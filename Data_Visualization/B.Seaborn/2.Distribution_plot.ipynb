# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Distribution Plot**
# Used to visualize quantitative data.

# %% [markdown]
# Different Plots to Visualize Distribution of dataset:
# * distplot/histplot
# * jointplot
# * pairplot
# * rugplot

# %% [markdown]
# .load_dataset("*dataset_name*")
# * To fetch data sets are provided by seaborn itself

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# First identify quantitative and qualitative data:
# *Quantitative:*
# * total_bill
# * tip
# *Qualitative( Categorical):*
# * sex
# * smoker
# * day
# * time
# * size (as only 6 unique values are present in large)

# %% [markdown]
# 1. **Distplot/ Histplot**
# * Used to make a single histogram
# * sns.displot/histplot(*column*, bins = *range of data taken at once*, kde = *boolean, kernel density estimation*)

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'], bins = 20, kde=True,)
plt.subplot(1,2,2)
sns.histplot(df['tip'], bins = 20, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# **Joint Plot**
# * Used to compare 2 plots
# * sns.jointplot( x = "*col_name*", y = "*col_name*", data = *data_frame*, kind = *type_of_plot (default = scatter)* )
# * *Literals in kind*: kind = ["scatter", "hist", "kde", "hex", "reg", "resid"]

# %%
sns.jointplot(
    x = "total_bill",
    y = "tip",
    data = df,
    kind = 'scatter'
)

# %%
sns.jointplot(
    x = "total_bill",
    y = "tip",
    data = df,
    kind = 'reg'
)

# %%
sns.jointplot(
    x = "total_bill",
    y = "tip",
    data = df,
    kind = 'hist',
    hue='smoker'
)

# %% [markdown]
# **Pair Plot**

# %% [markdown]
# * A pairplot shows the relationship between every pair of numerical columns in a dataset
# * sns.pairplot(*df_name*, hue = "*basis to categorize*")

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='size', palette="rainbow")

# %% [markdown]
# **Rug Plot**
# * Displays individual data points as small tick marks along x-axis
# * sns.rugplot(df)

# %%
sns.rugplot(df)
# Out:
# <Axes: >

# %%
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip'>
