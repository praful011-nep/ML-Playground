# %% [markdown]
# ****Matplotlib****

# %% [markdown]
# Plotting library in Python for creating interactive, animated and static visualization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Matplotlib Basics**

# %%
a = np.linspace(0,5,11)
a
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
b = a **2
b
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# <pre>
# <i><b>Making a plot</i></b>
#     plt.plot(<i>x-axis, y-axis</i>)
# <i><b>Adding labels</i></b>
#     plt.title("<i>title</i>")
#     plt.xlabel("")
#     plt.ylabel("")
# </pre>

# %% [markdown]
# **Note:**
# All the labels should be in the same cell as the plot funciton

# %%
plt.plot(
    a,
    b
)
plt.title("First plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# **Subplots in Matplotlib**

# %% [markdown]
# Multiple plots at same time

# %% [markdown]
# plt.subplot(*no of rows, no of columns, selected subplot*)

# %% [markdown]
# *To plot in any of the subplot*
# Just use plot function just below the respective subplot funciton

# %% [markdown]
# Subplots cannot be selected normally

# %%
plt.subplot(2,2,1)
plt.plot(b,a)
plt.subplot(2,2,2)
plt.plot(a,b)
plt.subplot(2,2,3)
m = plt.plot(a,b-2)
plt.subplot(2,2,4)
plt.plot(b+5,a**2)

# %% [markdown]
# **Object Oriented Way**

# %% [markdown]
# To select subplots, objected oriented way is used

# %% [markdown]
# As the canvas works as an image. So, the subplots cannot change positions
# i.e. *Have full control over canvas*

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %% [markdown]
# <pre>
# <b>.figure:</b>Creates the canvas
# .figure(figsize=<i>(width,height)</i>,dpi=<i>how much to pixelate</i>)
# The attributes are optional. In default figsize=(6.4,4.8) and dpi = 100
# <b>.add_axes:</b> it specifies size and position of the object
# .add_axes([
#     <i>move along x-axis<i>,
#     <i>move along y-axis<i>,
#     <i>width<i>,
#     <i>height<i>
# ])
# </pre>

# %%
fig = plt.figure(figsize=(12,8), dpi=100)
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(a,b)
axis2 = fig.add_axes([0.2,0.55,.5,.5])
axis2.plot(a,b)

# %% [markdown]
# **Types of Plots**

# %% [markdown]
# Scatter Plot

# %%
plt.scatter(a,b)

# %% [markdown]
# Histogram

# %%
data=np.random.randint(10,1000,10)
plt.hist(data)
data
# Out:
# array([630, 956, 851, 111, 383, 867, 827, 501, 625, 341], dtype=int32)

# %% [markdown]
# Box Plot

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28ec31d3620>,
#   <matplotlib.lines.Line2D at 0x28ec31d3770>],
#  'caps': [<matplotlib.lines.Line2D at 0x28ec31d38c0>,
#   <matplotlib.lines.Line2D at 0x28ec31d3a10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28ec31d34d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28ec31d3b60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28ec31d3cb0>],
#  'means': []}

# %% [markdown]
# **Saving Plots**

# %% [markdown]
# plt.savefig("*filename*")

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(a,b)
plt.savefig("firstplot.png")
